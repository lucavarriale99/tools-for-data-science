# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Luca Varriale**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I am passionate about statistics, maths and data and I love the concept of generate performance from them through different ways*

# %% [markdown]
# ### My code will  execute a very difficult operation ###

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# 1. numbered list
# 2. second item

# %% [markdown]
# - bulleted list
# - second item
#   - sub

# %% [markdown]
# ***
